# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/panama/panama_papers.edges.csv")
# Out:
# C:\Users\Yann-Axel\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
val_counts_per_col = []
for col in df.columns :
    values = df[col].value_counts()
    val_counts_per_col.append(values)

# %%
val_counts_per_col[3][val_counts_per_col[3]>10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['START_ID', 'TYPE', 'END_ID', 'link', 'start_date', 'end_date',
#        'sourceID', 'valid_until'],
#       dtype='object')
